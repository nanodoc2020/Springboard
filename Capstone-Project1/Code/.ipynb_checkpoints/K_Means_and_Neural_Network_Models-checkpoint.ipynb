# %% [markdown]
# # Unsupervised Learning
#
# This notebook contains code and analysis for a K-Means clustering algorithm and a small neural network both trained on the seeds dataset. All data has been previously cleaned and prepared in separate notebooks. Performance will be compared, along with that of models from the Logistic_Regression notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.preprocessing import label_binarize
from sklearn.metrics import classification_report, roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.callbacks import EarlyStopping, History

# %%
# Read the data into a dataframe
seeds = pd.read_csv('seeds.csv')

# Create versions of X and y with dropped superfluous columns
X = seeds.drop(['compactness', 'class'], axis=1)
X2 = seeds.drop(['compactness', 'perimeter', 'class'], axis=1)
X3 = seeds.drop(['compactness', 'area', 'class'], axis=1)

y = seeds.loc[:,'class']

# Display the seeds dataframe
seeds.head()

# %%
# Create training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y, test_size=.2, random_state=42)
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y, test_size=.2, random_state=42)

# %% [markdown]
# ## K-means Clustering

# %%
# Create classifiers
kmn = KMeans(max_iter=5000)
kmn2 = KMeans(max_iter=5000)
kmn3 = KMeans(max_iter=5000)

# Fit the classifiers 
kmn.fit(X_train)
kmn2.fit(X2_train)
kmn3.fit(X3_train)

# Get cluster centers and predicted labels
cluster_centers=kmn.cluster_centers_
cluster_centers2=kmn2.cluster_centers_
cluster_centers3=kmn3.cluster_centers_

labels=kmn.labels_
labels2=kmn2.labels_
labels3=kmn3.labels_

# %%
# Check for accuracy directly
outcome = labels==y_train
outcome2 = labels2==y2_train
outcome3 = labels3==y3_train

print('\nPercent correct on training set:',round(sum(outcome)/len(outcome)*100, 3),'%')
print('\nPercent correct on training set 2:',round(sum(outcome2)/len(outcome2)*100, 3),'%')
print('\nPercent correct on training set 3:',round(sum(outcome3)/len(outcome3)*100, 3),'%')
# Out:
# Percent correct on training set: 0.0 %
#
# Percent correct on training set 2: 9.524 %
#
# Percent correct on training set 3: 14.881 %

# %%
# Predict on the test set
prediction = kmn.predict(X_test)
prediction2 = kmn2.predict(X2_test)
prediction3 = kmn3.predict(X3_test)

# Check for accuracy directly
outcome = prediction==y_test
outcome2 = prediction2==y2_test
outcome3 = prediction3==y3_test
print('\nPercent correct on test set:',round(sum(outcome)/len(outcome)*100, 3),'%')
print('\nPercent correct on test set 2:',round(sum(outcome2)/len(outcome2)*100, 3),'%')
print('\nPercent correct on test set 3:',round(sum(outcome3)/len(outcome3)*100, 3),'%')
# Out:
# Percent correct on test set: 0.0 %
#
# Percent correct on test set 2: 9.524 %
#
# Percent correct on test set 3: 2.381 %

# %% [markdown]
# The K-means classifier does not perform as well as logistic regression or even naive Bayes models. Even with highly correlated features removed, the model performs poorly. This is likely due to the limited data size paired with a train_test_split that may include the outliers in the test set. It would be very difficult to correctly classify seeds whose geometric profiles overlap. The supervised k-nearest-neighbors model provides better results.

# %% [markdown]
# ## Neural Network

# %%
# Specify parameters
num_nodes = len(X_train.columns)*2
num_epochs = 1000
stop_pat = 25
out_nodes = 4

# Create the model
nn = Sequential()
nn2 = Sequential()
nn3 = Sequential()

# Specify the input dimension
in_dim = len(X_train.columns)
in2_dim = len(X2_train.columns)
in3_dim = len(X3_train.columns)

# Add layers to the models
nn.add(Dense(num_nodes, activation='relu', input_dim=in_dim))
nn.add(Dense(num_nodes, activation='relu'))
nn.add(Dense(num_nodes, activation='relu'))

nn2.add(Dense(num_nodes, activation='relu', input_dim=in2_dim))
nn2.add(Dense(num_nodes, activation='relu'))
nn2.add(Dense(num_nodes, activation='relu'))

nn3.add(Dense(num_nodes, activation='relu', input_dim=in3_dim))
nn3.add(Dense(num_nodes, activation='relu'))
nn3.add(Dense(num_nodes, activation='relu'))

# Add the output layer
nn.add(Dense(out_nodes, activation = 'softmax'))
nn2.add(Dense(out_nodes, activation = 'softmax'))
nn3.add(Dense(out_nodes, activation = 'softmax'))

# Compile the models
nn.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
nn2.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
nn3.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early_stopping_monitor
early_stopping_monitor = EarlyStopping(patience=stop_pat)

# %%
# Fit the models to the training data
nn_fit = nn.fit(X_train, y_train, epochs=num_epochs, validation_split=.3, callbacks=[early_stopping_monitor], 
                validation_data=(X_test, y_test), verbose=1)
nn2_fit = nn2.fit(X2_train, y2_train, epochs=num_epochs, validation_split=.3, callbacks=[early_stopping_monitor], 
                validation_data=(X2_test, y2_test), verbose=1)
nn3_fit = nn3.fit(X3_train, y3_train, epochs=num_epochs, validation_split=.3, callbacks=[early_stopping_monitor], 
                validation_data=(X3_test, y3_test), verbose=1)
# Out:
# Train on 168 samples, validate on 42 samples
# Epoch 1/1000
# 168/168 [==============================] - 2s 11ms/step - loss: 1.5982 - accuracy: 0.3333 - val_loss: 1.6448 - val_accuracy: 0.3333
# Epoch 2/1000
# 168/168 [==============================] - 0s 393us/step - loss: 1.4084 - accuracy: 0.3333 - val_loss: 1.4367 - val_accuracy: 0.3333
# Epoch 3/1000
# 168/168 [==============================] - 0s 440us/step - loss: 1.2814 - accuracy: 0.3333 - val_loss: 1.3056 - val_accuracy: 0.3333
# Epoch 4/1000
# 168/168 [==============================] - 0s 559us/step - loss: 1.2104 - accuracy: 0.3333 - val_loss: 1.2352 - val_accuracy: 0.3333
# Epoch 5/1000
# 168/168 [==============================] - 0s 333us/step - loss: 1.1820 - accuracy: 0.3333 - val_loss: 1.2238 - val_accuracy: 0.3333
# Epoch 6/1000
# 168/168 [==============================] - 0s 351us/step - loss: 1.1724 - accuracy: 0.3333 - val_loss: 1.2150 - val_accuracy: 0.3333
# Epoch 7/1000
# 168/168 [==============================] - 0s 333us/step - loss: 1.1560 - accuracy: 0.3333 - val_loss: 1.2137 - val_accuracy: 0.3333
# Epoch 8/1000
# 168/168 [==============================] - 0s 363us/step - loss: 1.1467 - accuracy: 0.3333 - val_loss: 1.1995 - val_accuracy: 0.3333
# Epoch 9/1000
# 168/168 [==============================] - 0s 381us/step - loss: 1.1362 - accuracy: 0.3333 - val_loss: 1.1731 - val_accuracy: 0.3333
# Epoch 10/1000
# 168/168 [==============================] - 0s 399us/step - loss: 1.1257 - accuracy: 0.3333 - val_loss: 1.1702 - val_accuracy: 0.3333
# Epoch 11/1000
# 168/168 [==============================] - 0s 381us/step - loss: 1.1148 - accuracy: 0.3333 - val_loss: 1.1506 - val_accuracy: 0.3333
# Epoch 12/1000
# 168/168 [==============================] - 0s 458us/step - loss: 1.1035 - accuracy: 0.3333 - val_loss: 1.1376 - val_accuracy: 0.3333
# Epoch 13/1000
# 168/168 [==============================] - 0s 357us/step - loss: 1.0940 - accuracy: 0.3333 - val_loss: 1.1323 - val_accuracy: 0.3333
# Epoch 14/1000
# 168/168 [==============================] - 0s 345us/step - loss: 1.0846 - accuracy: 0.3333 - val_loss: 1.1336 - val_accuracy: 0.3333
# Epoch 15/1000
# 168/168 [==============================] - 0s 327us/step - loss: 1.0720 - accuracy: 0.3333 - val_loss: 1.1067 - val_accuracy: 0.3333
# Epoch 16/1000
# 168/168 [==============================] - 0s 321us/step - loss: 1.0618 - accuracy: 0.3333 - val_loss: 1.0957 - val_accuracy: 0.3333
# Epoch 17/1000
# 168/168 [==============================] - 0s 327us/step - loss: 1.0500 - accuracy: 0.3333 - val_loss: 1.0811 - val_accuracy: 0.3333
# Epoch 18/1000
# 168/168 [==============================] - 0s 333us/step - loss: 1.0379 - accuracy: 0.3333 - val_loss: 1.0713 - val_accuracy: 0.3333
# Epoch 19/1000
# 168/168 [==============================] - 0s 327us/step - loss: 1.0272 - accuracy: 0.3333 - val_loss: 1.0517 - val_accuracy: 0.3333
# Epoch 20/1000
# 168/168 [==============================] - 0s 351us/step - loss: 1.0148 - accuracy: 0.3333 - val_loss: 1.0357 - val_accuracy: 0.3333
# Epoch 21/1000
# 168/168 [==============================] - 0s 321us/step - loss: 1.0026 - accuracy: 0.3333 - val_loss: 1.0330 - val_accuracy: 0.3333
# Epoch 22/1000
# 168/168 [==============================] - 0s 357us/step - loss: 0.9912 - accuracy: 0.3333 - val_loss: 1.0155 - val_accuracy: 0.3333
# Epoch 23/1000
# 168/168 [==============================] - 0s 315us/step - loss: 0.9773 - accuracy: 0.3333 - val_loss: 0.9961 - val_accuracy: 0.3333
# Epoch 24/1000
# 168/168 [==============================] - 0s 345us/step - loss: 0.9659 - accuracy: 0.3333 - val_loss: 0.9845 - val_accuracy: 0.3333
# Epoch 25/1000
# 168/168 [==============================] - 0s 357us/step - loss: 0.9534 - accuracy: 0.3571 - val_loss: 0.9629 - val_accuracy: 0.3571
# Epoch 26/1000
# 168/168 [==============================] - 0s 387us/step - loss: 0.9393 - accuracy: 0.3869 - val_loss: 0.9622 - val_accuracy: 0.3571
# Epoch 27/1000
# 168/168 [==============================] - 0s 363us/step - loss: 0.9315 - accuracy: 0.3929 - val_loss: 0.9488 - val_accuracy: 0.4286
# Epoch 28/1000
# 168/168 [==============================] - 0s 363us/step - loss: 0.9148 - accuracy: 0.4643 - val_loss: 0.9193 - val_accuracy: 0.5714
# Epoch 29/1000
# 168/168 [==============================] - 0s 309us/step - loss: 0.9020 - accuracy: 0.5179 - val_loss: 0.9103 - val_accuracy: 0.5238
# Epoch 30/1000
# 168/168 [==============================] - 0s 280us/step - loss: 0.8887 - accuracy: 0.4821 - val_loss: 0.9160 - val_accuracy: 0.5000
# Epoch 31/1000
# 168/168 [==============================] - 0s 339us/step - loss: 0.8752 - accuracy: 0.5179 - val_loss: 0.8716 - val_accuracy: 0.5952
# Epoch 32/1000
# 168/168 [==============================] - 0s 286us/step - loss: 0.8608 - accuracy: 0.5595 - val_loss: 0.8635 - val_accuracy: 0.5714
# Epoch 33/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.8463 - accuracy: 0.5476 - val_loss: 0.8671 - val_accuracy: 0.5952
# Epoch 34/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.8384 - accuracy: 0.5714 - val_loss: 0.8289 - val_accuracy: 0.6429
# Epoch 35/1000
# 168/168 [==============================] - ETA: 0s - loss: 0.8461 - accuracy: 0.71 - 0s 291us/step - loss: 0.8228 - accuracy: 0.6131 - val_loss: 0.8125 - val_accuracy: 0.6429
# Epoch 36/1000
# 168/168 [==============================] - 0s 303us/step - loss: 0.8090 - accuracy: 0.5833 - val_loss: 0.8304 - val_accuracy: 0.5952
# Epoch 37/1000
# 168/168 [==============================] - 0s 286us/step - loss: 0.7990 - accuracy: 0.5714 - val_loss: 0.7939 - val_accuracy: 0.6667
# Epoch 38/1000
# 168/168 [==============================] - 0s 297us/step - loss: 0.7848 - accuracy: 0.6190 - val_loss: 0.7716 - val_accuracy: 0.7143
# Epoch 39/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.7708 - accuracy: 0.6429 - val_loss: 0.7830 - val_accuracy: 0.6667
# Epoch 40/1000
# 168/168 [==============================] - 0s 286us/step - loss: 0.7601 - accuracy: 0.6667 - val_loss: 0.7527 - val_accuracy: 0.7857
# Epoch 41/1000
# 168/168 [==============================] - 0s 327us/step - loss: 0.7467 - accuracy: 0.6964 - val_loss: 0.7421 - val_accuracy: 0.8095
# Epoch 42/1000
# 168/168 [==============================] - 0s 303us/step - loss: 0.7370 - accuracy: 0.7083 - val_loss: 0.7292 - val_accuracy: 0.7857
# Epoch 43/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.7240 - accuracy: 0.6964 - val_loss: 0.7368 - val_accuracy: 0.7857
# Epoch 44/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.7154 - accuracy: 0.7024 - val_loss: 0.7018 - val_accuracy: 0.7857
# Epoch 45/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.7032 - accuracy: 0.7262 - val_loss: 0.6903 - val_accuracy: 0.7857
# Epoch 46/1000
# 168/168 [==============================] - 0s 280us/step - loss: 0.6938 - accuracy: 0.6845 - val_loss: 0.6847 - val_accuracy: 0.7143
# Epoch 47/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.6830 - accuracy: 0.6429 - val_loss: 0.6770 - val_accuracy: 0.7143
# Epoch 48/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.6727 - accuracy: 0.6607 - val_loss: 0.6574 - val_accuracy: 0.7143
# Epoch 49/1000
# 168/168 [==============================] - 0s 280us/step - loss: 0.6661 - accuracy: 0.7083 - val_loss: 0.6609 - val_accuracy: 0.7857
# Epoch 50/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.6547 - accuracy: 0.7202 - val_loss: 0.6418 - val_accuracy: 0.7143
# Epoch 51/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.6476 - accuracy: 0.6905 - val_loss: 0.6313 - val_accuracy: 0.7143
# Epoch 52/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.6380 - accuracy: 0.6726 - val_loss: 0.6412 - val_accuracy: 0.7143
# Epoch 53/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.6308 - accuracy: 0.7262 - val_loss: 0.6312 - val_accuracy: 0.8095
# Epoch 54/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.6256 - accuracy: 0.8095 - val_loss: 0.6213 - val_accuracy: 0.8333
# Epoch 55/1000
# 168/168 [==============================] - 0s 274us/step - loss: 0.6167 - accuracy: 0.7798 - val_loss: 0.6044 - val_accuracy: 0.8333
# Epoch 56/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.6099 - accuracy: 0.7381 - val_loss: 0.6052 - val_accuracy: 0.7619
# Epoch 57/1000
# 168/168 [==============================] - 0s 286us/step - loss: 0.6030 - accuracy: 0.7440 - val_loss: 0.5980 - val_accuracy: 0.7619
# Epoch 58/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.5960 - accuracy: 0.7202 - val_loss: 0.5835 - val_accuracy: 0.7381
# Epoch 59/1000
# 168/168 [==============================] - 0s 280us/step - loss: 0.5999 - accuracy: 0.7024 - val_loss: 0.5743 - val_accuracy: 0.7619
# Epoch 60/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.5818 - accuracy: 0.7321 - val_loss: 0.6008 - val_accuracy: 0.7619
# Epoch 61/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.5854 - accuracy: 0.7500 - val_loss: 0.5934 - val_accuracy: 0.8095
# Epoch 62/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.5755 - accuracy: 0.8452 - val_loss: 0.5766 - val_accuracy: 0.8333
# Epoch 63/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.5736 - accuracy: 0.8274 - val_loss: 0.5557 - val_accuracy: 0.8333
# Epoch 64/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.5637 - accuracy: 0.7500 - val_loss: 0.5695 - val_accuracy: 0.7381
# Epoch 65/1000
# 168/168 [==============================] - 0s 210us/step - loss: 0.5593 - accuracy: 0.7262 - val_loss: 0.5608 - val_accuracy: 0.7619
# Epoch 66/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.5526 - accuracy: 0.8214 - val_loss: 0.5505 - val_accuracy: 0.8333
# Epoch 67/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.5504 - accuracy: 0.8393 - val_loss: 0.5436 - val_accuracy: 0.8333
# Epoch 68/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.5477 - accuracy: 0.7857 - val_loss: 0.5398 - val_accuracy: 0.7619
# Epoch 69/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.5456 - accuracy: 0.7202 - val_loss: 0.5581 - val_accuracy: 0.7381
# Epoch 70/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.5382 - accuracy: 0.7679 - val_loss: 0.5516 - val_accuracy: 0.8095
# Epoch 71/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.5291 - accuracy: 0.8571 - val_loss: 0.5400 - val_accuracy: 0.8333
# Epoch 72/1000
# 168/168 [==============================] - 0s 381us/step - loss: 0.5255 - accuracy: 0.8512 - val_loss: 0.5302 - val_accuracy: 0.8333
# Epoch 73/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.5171 - accuracy: 0.7976 - val_loss: 0.5160 - val_accuracy: 0.7619
# Epoch 74/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.5146 - accuracy: 0.7560 - val_loss: 0.5177 - val_accuracy: 0.7857
# Epoch 75/1000
# 168/168 [==============================] - 0s 210us/step - loss: 0.5158 - accuracy: 0.7976 - val_loss: 0.5059 - val_accuracy: 0.8571
# Epoch 76/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.5026 - accuracy: 0.8512 - val_loss: 0.5273 - val_accuracy: 0.7857
# Epoch 77/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.5073 - accuracy: 0.8214 - val_loss: 0.5273 - val_accuracy: 0.7857
# Epoch 78/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.4999 - accuracy: 0.8393 - val_loss: 0.4987 - val_accuracy: 0.8333
# Epoch 79/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.4923 - accuracy: 0.8393 - val_loss: 0.5005 - val_accuracy: 0.8095
# Epoch 80/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.4837 - accuracy: 0.8393 - val_loss: 0.4899 - val_accuracy: 0.8333
# Epoch 81/1000
# 168/168 [==============================] - 0s 238us/step - loss: 0.4812 - accuracy: 0.8393 - val_loss: 0.4895 - val_accuracy: 0.8333
# Epoch 82/1000
# 168/168 [==============================] - 0s 238us/step - loss: 0.4750 - accuracy: 0.8512 - val_loss: 0.4907 - val_accuracy: 0.8095
# Epoch 83/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.4712 - accuracy: 0.8571 - val_loss: 0.4846 - val_accuracy: 0.8333
# Epoch 84/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.4688 - accuracy: 0.8452 - val_loss: 0.4761 - val_accuracy: 0.8095
# Epoch 85/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.4624 - accuracy: 0.8333 - val_loss: 0.4835 - val_accuracy: 0.8095
# Epoch 86/1000
# 168/168 [==============================] - 0s 238us/step - loss: 0.4597 - accuracy: 0.8393 - val_loss: 0.4832 - val_accuracy: 0.8333
# Epoch 87/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.4524 - accuracy: 0.8810 - val_loss: 0.4641 - val_accuracy: 0.8333
# Epoch 88/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4508 - accuracy: 0.8810 - val_loss: 0.4623 - val_accuracy: 0.8333
# Epoch 89/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.4459 - accuracy: 0.8690 - val_loss: 0.4581 - val_accuracy: 0.8333
# Epoch 90/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.4408 - accuracy: 0.8690 - val_loss: 0.4515 - val_accuracy: 0.8571
# Epoch 91/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.4408 - accuracy: 0.8810 - val_loss: 0.4751 - val_accuracy: 0.8095
# Epoch 92/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4333 - accuracy: 0.8988 - val_loss: 0.4494 - val_accuracy: 0.8333
# Epoch 93/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.4378 - accuracy: 0.8869 - val_loss: 0.4365 - val_accuracy: 0.8571
# Epoch 94/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.4286 - accuracy: 0.9226 - val_loss: 0.4558 - val_accuracy: 0.8333
# Epoch 95/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.4217 - accuracy: 0.8810 - val_loss: 0.4485 - val_accuracy: 0.8095
# Epoch 96/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.4161 - accuracy: 0.8690 - val_loss: 0.4291 - val_accuracy: 0.8571
# Epoch 97/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.4125 - accuracy: 0.8750 - val_loss: 0.4310 - val_accuracy: 0.8333
# Epoch 98/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4030 - accuracy: 0.8929 - val_loss: 0.4270 - val_accuracy: 0.8571
# Epoch 99/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4011 - accuracy: 0.9107 - val_loss: 0.4297 - val_accuracy: 0.8571
# Epoch 100/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.3978 - accuracy: 0.8988 - val_loss: 0.4124 - val_accuracy: 0.8571
# Epoch 101/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.3965 - accuracy: 0.8929 - val_loss: 0.4151 - val_accuracy: 0.8571
# Epoch 102/1000
# 168/168 [==============================] - 0s 189us/step - loss: 0.3868 - accuracy: 0.9048 - val_loss: 0.4266 - val_accuracy: 0.8571
# Epoch 103/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.3899 - accuracy: 0.9167 - val_loss: 0.4281 - val_accuracy: 0.8810
# Epoch 104/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.3815 - accuracy: 0.9107 - val_loss: 0.4078 - val_accuracy: 0.8571
# Epoch 105/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.3772 - accuracy: 0.8750 - val_loss: 0.4039 - val_accuracy: 0.8571
# Epoch 106/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.3764 - accuracy: 0.9345 - val_loss: 0.4011 - val_accuracy: 0.9048
# Epoch 107/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.3677 - accuracy: 0.8869 - val_loss: 0.4075 - val_accuracy: 0.8095
# Epoch 108/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.3728 - accuracy: 0.8929 - val_loss: 0.3893 - val_accuracy: 0.8810
# Epoch 109/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.3575 - accuracy: 0.9107 - val_loss: 0.4156 - val_accuracy: 0.8810
# Epoch 110/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.3601 - accuracy: 0.9345 - val_loss: 0.4090 - val_accuracy: 0.8571
# Epoch 111/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.3538 - accuracy: 0.9226 - val_loss: 0.3807 - val_accuracy: 0.8810
# Epoch 112/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.3504 - accuracy: 0.9286 - val_loss: 0.3873 - val_accuracy: 0.9286
# Epoch 113/1000
# 168/168 [==============================] - 0s 173us/step - loss: 0.3393 - accuracy: 0.9226 - val_loss: 0.3989 - val_accuracy: 0.8095
# Epoch 114/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.3413 - accuracy: 0.9048 - val_loss: 0.3750 - val_accuracy: 0.8810
# Epoch 115/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.3336 - accuracy: 0.9107 - val_loss: 0.3801 - val_accuracy: 0.9286
# Epoch 116/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.3321 - accuracy: 0.9167 - val_loss: 0.3904 - val_accuracy: 0.8333
# Epoch 117/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.3282 - accuracy: 0.9107 - val_loss: 0.3648 - val_accuracy: 0.8810
# Epoch 118/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.3187 - accuracy: 0.9167 - val_loss: 0.3783 - val_accuracy: 0.8333
# Epoch 119/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.3232 - accuracy: 0.9167 - val_loss: 0.3642 - val_accuracy: 0.9048
# Epoch 120/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.3126 - accuracy: 0.9167 - val_loss: 0.3668 - val_accuracy: 0.8810
# Epoch 121/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.3139 - accuracy: 0.9226 - val_loss: 0.3704 - val_accuracy: 0.8571
# Epoch 122/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.3167 - accuracy: 0.9286 - val_loss: 0.3868 - val_accuracy: 0.8571
# Epoch 123/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.3186 - accuracy: 0.9226 - val_loss: 0.3542 - val_accuracy: 0.9048
# Epoch 124/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.3110 - accuracy: 0.9286 - val_loss: 0.3717 - val_accuracy: 0.8571
# Epoch 125/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.3023 - accuracy: 0.9226 - val_loss: 0.3473 - val_accuracy: 0.9048
# Epoch 126/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.2967 - accuracy: 0.9405 - val_loss: 0.3555 - val_accuracy: 0.8571
# Epoch 127/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.2917 - accuracy: 0.9226 - val_loss: 0.3546 - val_accuracy: 0.8571
# Epoch 128/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2871 - accuracy: 0.9345 - val_loss: 0.3474 - val_accuracy: 0.8571
# Epoch 129/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.2902 - accuracy: 0.9345 - val_loss: 0.3352 - val_accuracy: 0.9048
# Epoch 130/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2825 - accuracy: 0.9345 - val_loss: 0.3579 - val_accuracy: 0.8571
# Epoch 131/1000
# 168/168 [==============================] - 0s 174us/step - loss: 0.2822 - accuracy: 0.9226 - val_loss: 0.3397 - val_accuracy: 0.8810
# Epoch 132/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2781 - accuracy: 0.9345 - val_loss: 0.3434 - val_accuracy: 0.8571
# Epoch 133/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.2726 - accuracy: 0.9345 - val_loss: 0.3384 - val_accuracy: 0.8571
# Epoch 134/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2707 - accuracy: 0.9405 - val_loss: 0.3290 - val_accuracy: 0.8810
# Epoch 135/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2683 - accuracy: 0.9345 - val_loss: 0.3390 - val_accuracy: 0.8571
# Epoch 136/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2697 - accuracy: 0.9464 - val_loss: 0.3273 - val_accuracy: 0.8810
# Epoch 137/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2652 - accuracy: 0.9286 - val_loss: 0.3329 - val_accuracy: 0.8571
# Epoch 138/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2585 - accuracy: 0.9345 - val_loss: 0.3246 - val_accuracy: 0.9048
# Epoch 139/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.2770 - accuracy: 0.9167 - val_loss: 0.3490 - val_accuracy: 0.8571
# Epoch 140/1000
# 168/168 [==============================] - 0s 172us/step - loss: 0.2845 - accuracy: 0.9167 - val_loss: 0.3813 - val_accuracy: 0.8810
# Epoch 141/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2646 - accuracy: 0.9167 - val_loss: 0.3234 - val_accuracy: 0.8810
# Epoch 142/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2725 - accuracy: 0.9226 - val_loss: 0.3162 - val_accuracy: 0.8810
# Epoch 143/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2672 - accuracy: 0.9107 - val_loss: 0.3287 - val_accuracy: 0.8571
# Epoch 144/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2459 - accuracy: 0.9345 - val_loss: 0.3142 - val_accuracy: 0.9048
# Epoch 145/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2516 - accuracy: 0.9345 - val_loss: 0.3387 - val_accuracy: 0.8571
# Epoch 146/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2458 - accuracy: 0.9405 - val_loss: 0.3245 - val_accuracy: 0.8571
# Epoch 147/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2411 - accuracy: 0.9345 - val_loss: 0.3148 - val_accuracy: 0.8810
# Epoch 148/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2392 - accuracy: 0.9345 - val_loss: 0.3089 - val_accuracy: 0.8810
# Epoch 149/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2373 - accuracy: 0.9464 - val_loss: 0.2996 - val_accuracy: 0.8810
# Epoch 150/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2454 - accuracy: 0.9226 - val_loss: 0.3051 - val_accuracy: 0.8810
# Epoch 151/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2448 - accuracy: 0.9167 - val_loss: 0.3102 - val_accuracy: 0.8810
# Epoch 152/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.2409 - accuracy: 0.9226 - val_loss: 0.3067 - val_accuracy: 0.8810
# Epoch 153/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2269 - accuracy: 0.9405 - val_loss: 0.3070 - val_accuracy: 0.8810
# Epoch 154/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2396 - accuracy: 0.9286 - val_loss: 0.3252 - val_accuracy: 0.8571
# Epoch 155/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2304 - accuracy: 0.9405 - val_loss: 0.3246 - val_accuracy: 0.8571
# Epoch 156/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2325 - accuracy: 0.9345 - val_loss: 0.3028 - val_accuracy: 0.8810
# Epoch 157/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2230 - accuracy: 0.9405 - val_loss: 0.3011 - val_accuracy: 0.8810
# Epoch 158/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2218 - accuracy: 0.9405 - val_loss: 0.2909 - val_accuracy: 0.9048
# Epoch 159/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2204 - accuracy: 0.9405 - val_loss: 0.2916 - val_accuracy: 0.8810
# Epoch 160/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2205 - accuracy: 0.9405 - val_loss: 0.3075 - val_accuracy: 0.8571
# Epoch 161/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.2222 - accuracy: 0.9345 - val_loss: 0.3204 - val_accuracy: 0.8571
# Epoch 162/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2136 - accuracy: 0.9464 - val_loss: 0.2988 - val_accuracy: 0.8810
# Epoch 163/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2415 - accuracy: 0.9167 - val_loss: 0.2904 - val_accuracy: 0.8810
# Epoch 164/1000
# 168/168 [==============================] - 0s 167us/step - loss: 0.2103 - accuracy: 0.9464 - val_loss: 0.3086 - val_accuracy: 0.8571
# Epoch 165/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2240 - accuracy: 0.9226 - val_loss: 0.2950 - val_accuracy: 0.8810
# Epoch 166/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2184 - accuracy: 0.9286 - val_loss: 0.2844 - val_accuracy: 0.8810
# Epoch 167/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.2060 - accuracy: 0.9464 - val_loss: 0.3227 - val_accuracy: 0.8571
# Epoch 168/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.2317 - accuracy: 0.9167 - val_loss: 0.3395 - val_accuracy: 0.8810
# Epoch 169/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2090 - accuracy: 0.9464 - val_loss: 0.2883 - val_accuracy: 0.8810
# Epoch 170/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.2118 - accuracy: 0.9345 - val_loss: 0.2690 - val_accuracy: 0.9048
# Epoch 171/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.2165 - accuracy: 0.9226 - val_loss: 0.2860 - val_accuracy: 0.8810
# Epoch 172/1000
# 168/168 [==============================] - 0s 172us/step - loss: 0.2100 - accuracy: 0.9226 - val_loss: 0.2994 - val_accuracy: 0.8571
# Epoch 173/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.2082 - accuracy: 0.9405 - val_loss: 0.2794 - val_accuracy: 0.8810
# Epoch 174/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.2033 - accuracy: 0.9405 - val_loss: 0.2892 - val_accuracy: 0.8810
# Epoch 175/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.2036 - accuracy: 0.9405 - val_loss: 0.2884 - val_accuracy: 0.8810
# Epoch 176/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2052 - accuracy: 0.9405 - val_loss: 0.2815 - val_accuracy: 0.8810
# Epoch 177/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2009 - accuracy: 0.9464 - val_loss: 0.2877 - val_accuracy: 0.8810
# Epoch 178/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2022 - accuracy: 0.9524 - val_loss: 0.2919 - val_accuracy: 0.8810
# Epoch 179/1000
# 168/168 [==============================] - 0s 167us/step - loss: 0.2011 - accuracy: 0.9464 - val_loss: 0.2833 - val_accuracy: 0.8810
# Epoch 180/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.2006 - accuracy: 0.9464 - val_loss: 0.2817 - val_accuracy: 0.8810
# Epoch 181/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.2052 - accuracy: 0.9286 - val_loss: 0.2829 - val_accuracy: 0.8810
# Epoch 182/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.2170 - accuracy: 0.9345 - val_loss: 0.2874 - val_accuracy: 0.8810
# Epoch 183/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.1992 - accuracy: 0.9405 - val_loss: 0.3067 - val_accuracy: 0.8333
# Epoch 184/1000
# 168/168 [==============================] - 0s 315us/step - loss: 0.2034 - accuracy: 0.9345 - val_loss: 0.2988 - val_accuracy: 0.8571
# Epoch 185/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.1951 - accuracy: 0.9464 - val_loss: 0.2830 - val_accuracy: 0.8810
# Epoch 186/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.1965 - accuracy: 0.9345 - val_loss: 0.2772 - val_accuracy: 0.8810
# Epoch 187/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.1947 - accuracy: 0.9405 - val_loss: 0.2724 - val_accuracy: 0.8810
# Epoch 188/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.1991 - accuracy: 0.9226 - val_loss: 0.2716 - val_accuracy: 0.8810
# Epoch 189/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.2017 - accuracy: 0.9345 - val_loss: 0.3051 - val_accuracy: 0.8571
# Epoch 190/1000
# 168/168 [==============================] - 0s 167us/step - loss: 0.1979 - accuracy: 0.9345 - val_loss: 0.3024 - val_accuracy: 0.8571
# Epoch 191/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2017 - accuracy: 0.9286 - val_loss: 0.2877 - val_accuracy: 0.8810
# Epoch 192/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.1889 - accuracy: 0.9405 - val_loss: 0.2815 - val_accuracy: 0.8810
# Epoch 193/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.1992 - accuracy: 0.9286 - val_loss: 0.2702 - val_accuracy: 0.8810
# Epoch 194/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.2005 - accuracy: 0.9286 - val_loss: 0.2923 - val_accuracy: 0.8810
# Epoch 195/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.1979 - accuracy: 0.9405 - val_loss: 0.3024 - val_accuracy: 0.8571
# Train on 168 samples, validate on 42 samples
# Epoch 1/1000
# 168/168 [==============================] - 2s 11ms/step - loss: 4.0898 - accuracy: 0.3155 - val_loss: 3.4535 - val_accuracy: 0.4048
# Epoch 2/1000
# 168/168 [==============================] - 0s 369us/step - loss: 3.5020 - accuracy: 0.3155 - val_loss: 2.9445 - val_accuracy: 0.4048
# Epoch 3/1000
# 168/168 [==============================] - 0s 345us/step - loss: 2.9594 - accuracy: 0.3155 - val_loss: 2.5082 - val_accuracy: 0.4048
# Epoch 4/1000
# 168/168 [==============================] - 0s 387us/step - loss: 2.4943 - accuracy: 0.2976 - val_loss: 2.1519 - val_accuracy: 0.3810
# Epoch 5/1000
# 168/168 [==============================] - 0s 369us/step - loss: 2.1160 - accuracy: 0.2560 - val_loss: 1.8759 - val_accuracy: 0.2143
# Epoch 6/1000
# 168/168 [==============================] - 0s 541us/step - loss: 1.8306 - accuracy: 0.1429 - val_loss: 1.6679 - val_accuracy: 0.0952
# Epoch 7/1000
# 168/168 [==============================] - 0s 393us/step - loss: 1.6237 - accuracy: 0.0774 - val_loss: 1.5551 - val_accuracy: 0.1190
# Epoch 8/1000
# 168/168 [==============================] - 0s 422us/step - loss: 1.4996 - accuracy: 0.1429 - val_loss: 1.4891 - val_accuracy: 0.0952
# Epoch 9/1000
# 168/168 [==============================] - 0s 381us/step - loss: 1.4241 - accuracy: 0.2500 - val_loss: 1.4494 - val_accuracy: 0.1667
# Epoch 10/1000
# 168/168 [==============================] - 0s 405us/step - loss: 1.3815 - accuracy: 0.2917 - val_loss: 1.4229 - val_accuracy: 0.3333
# Epoch 11/1000
# 168/168 [==============================] - 0s 387us/step - loss: 1.3470 - accuracy: 0.3036 - val_loss: 1.4012 - val_accuracy: 0.3571
# Epoch 12/1000
# 168/168 [==============================] - 0s 512us/step - loss: 1.3234 - accuracy: 0.3095 - val_loss: 1.3810 - val_accuracy: 0.3571
# Epoch 13/1000
# 168/168 [==============================] - 0s 292us/step - loss: 1.3022 - accuracy: 0.3095 - val_loss: 1.3612 - val_accuracy: 0.3571
# Epoch 14/1000
# 168/168 [==============================] - 0s 315us/step - loss: 1.2812 - accuracy: 0.3214 - val_loss: 1.3416 - val_accuracy: 0.3571
# Epoch 15/1000
# 168/168 [==============================] - 0s 351us/step - loss: 1.2609 - accuracy: 0.3095 - val_loss: 1.3193 - val_accuracy: 0.3095
# Epoch 16/1000
# 168/168 [==============================] - 0s 309us/step - loss: 1.2406 - accuracy: 0.2381 - val_loss: 1.2980 - val_accuracy: 0.1905
# Epoch 17/1000
# 168/168 [==============================] - 0s 333us/step - loss: 1.2186 - accuracy: 0.2798 - val_loss: 1.2754 - val_accuracy: 0.2381
# Epoch 18/1000
# 168/168 [==============================] - 0s 321us/step - loss: 1.1968 - accuracy: 0.3452 - val_loss: 1.2535 - val_accuracy: 0.2619
# Epoch 19/1000
# 168/168 [==============================] - 0s 309us/step - loss: 1.1733 - accuracy: 0.3512 - val_loss: 1.2296 - val_accuracy: 0.2619
# Epoch 20/1000
# 168/168 [==============================] - 0s 274us/step - loss: 1.1511 - accuracy: 0.3512 - val_loss: 1.1980 - val_accuracy: 0.2619
# Epoch 21/1000
# 168/168 [==============================] - 0s 309us/step - loss: 1.1267 - accuracy: 0.3750 - val_loss: 1.1677 - val_accuracy: 0.2619
# Epoch 22/1000
# 168/168 [==============================] - 0s 303us/step - loss: 1.1033 - accuracy: 0.3571 - val_loss: 1.1378 - val_accuracy: 0.3810
# Epoch 23/1000
# 168/168 [==============================] - 0s 327us/step - loss: 1.0799 - accuracy: 0.3631 - val_loss: 1.1064 - val_accuracy: 0.3810
# Epoch 24/1000
# 168/168 [==============================] - 0s 280us/step - loss: 1.0577 - accuracy: 0.4048 - val_loss: 1.0681 - val_accuracy: 0.4286
# Epoch 25/1000
# 168/168 [==============================] - 0s 357us/step - loss: 1.0285 - accuracy: 0.4643 - val_loss: 1.0283 - val_accuracy: 0.5238
# Epoch 26/1000
# 168/168 [==============================] - 0s 297us/step - loss: 1.0016 - accuracy: 0.5060 - val_loss: 0.9870 - val_accuracy: 0.6429
# Epoch 27/1000
# 168/168 [==============================] - 0s 297us/step - loss: 0.9765 - accuracy: 0.5655 - val_loss: 0.9581 - val_accuracy: 0.6667
# Epoch 28/1000
# 168/168 [==============================] - 0s 297us/step - loss: 0.9551 - accuracy: 0.5774 - val_loss: 0.9412 - val_accuracy: 0.6905
# Epoch 29/1000
# 168/168 [==============================] - 0s 321us/step - loss: 0.9389 - accuracy: 0.5893 - val_loss: 0.9268 - val_accuracy: 0.6905
# Epoch 30/1000
# 168/168 [==============================] - 0s 351us/step - loss: 0.9229 - accuracy: 0.6131 - val_loss: 0.9070 - val_accuracy: 0.6667
# Epoch 31/1000
# 168/168 [==============================] - 0s 297us/step - loss: 0.9071 - accuracy: 0.6310 - val_loss: 0.8866 - val_accuracy: 0.6667
# Epoch 32/1000
# 168/168 [==============================] - 0s 280us/step - loss: 0.8939 - accuracy: 0.6131 - val_loss: 0.8668 - val_accuracy: 0.6905
# Epoch 33/1000
# 168/168 [==============================] - 0s 274us/step - loss: 0.8793 - accuracy: 0.5952 - val_loss: 0.8501 - val_accuracy: 0.6429
# Epoch 34/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.8680 - accuracy: 0.5952 - val_loss: 0.8375 - val_accuracy: 0.6429
# Epoch 35/1000
# 168/168 [==============================] - 0s 297us/step - loss: 0.8563 - accuracy: 0.5952 - val_loss: 0.8314 - val_accuracy: 0.7143
# Epoch 36/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.8430 - accuracy: 0.6071 - val_loss: 0.8148 - val_accuracy: 0.6667
# Epoch 37/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.8339 - accuracy: 0.6250 - val_loss: 0.8051 - val_accuracy: 0.6429
# Epoch 38/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.8267 - accuracy: 0.5833 - val_loss: 0.7967 - val_accuracy: 0.6667
# Epoch 39/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.8186 - accuracy: 0.6190 - val_loss: 0.7913 - val_accuracy: 0.6905
# Epoch 40/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.8063 - accuracy: 0.6369 - val_loss: 0.7774 - val_accuracy: 0.6667
# Epoch 41/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.7974 - accuracy: 0.6369 - val_loss: 0.7699 - val_accuracy: 0.6667
# Epoch 42/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.7893 - accuracy: 0.6190 - val_loss: 0.7611 - val_accuracy: 0.6667
# Epoch 43/1000
# 168/168 [==============================] - 0s 238us/step - loss: 0.7810 - accuracy: 0.6369 - val_loss: 0.7546 - val_accuracy: 0.6905
# Epoch 44/1000
# 168/168 [==============================] - 0s 274us/step - loss: 0.7744 - accuracy: 0.6310 - val_loss: 0.7472 - val_accuracy: 0.6905
# Epoch 45/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.7664 - accuracy: 0.6012 - val_loss: 0.7394 - val_accuracy: 0.6667
# Epoch 46/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.7632 - accuracy: 0.6012 - val_loss: 0.7306 - val_accuracy: 0.6667
# Epoch 47/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.7532 - accuracy: 0.6250 - val_loss: 0.7252 - val_accuracy: 0.6667
# Epoch 48/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.7470 - accuracy: 0.6250 - val_loss: 0.7175 - val_accuracy: 0.6667
# Epoch 49/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.7421 - accuracy: 0.6310 - val_loss: 0.7126 - val_accuracy: 0.6905
# Epoch 50/1000
# 168/168 [==============================] - 0s 274us/step - loss: 0.7372 - accuracy: 0.6369 - val_loss: 0.7050 - val_accuracy: 0.6667
# Epoch 51/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.7312 - accuracy: 0.6310 - val_loss: 0.7030 - val_accuracy: 0.6905
# Epoch 52/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.7262 - accuracy: 0.6250 - val_loss: 0.6994 - val_accuracy: 0.6667
# Epoch 53/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.7213 - accuracy: 0.6012 - val_loss: 0.6965 - val_accuracy: 0.6667
# Epoch 54/1000
# 168/168 [==============================] - 0s 375us/step - loss: 0.7159 - accuracy: 0.6131 - val_loss: 0.6943 - val_accuracy: 0.6905
# Epoch 55/1000
# 168/168 [==============================] - 0s 321us/step - loss: 0.7098 - accuracy: 0.6250 - val_loss: 0.6924 - val_accuracy: 0.6905
# Epoch 56/1000
# 168/168 [==============================] - 0s 333us/step - loss: 0.7075 - accuracy: 0.6369 - val_loss: 0.6830 - val_accuracy: 0.6905
# Epoch 57/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.6988 - accuracy: 0.6310 - val_loss: 0.6782 - val_accuracy: 0.6667
# Epoch 58/1000
# 168/168 [==============================] - 0s 226us/step - loss: 0.6986 - accuracy: 0.6429 - val_loss: 0.6756 - val_accuracy: 0.6667
# Epoch 59/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.6907 - accuracy: 0.6369 - val_loss: 0.6691 - val_accuracy: 0.6905
# Epoch 60/1000
# 168/168 [==============================] - 0s 297us/step - loss: 0.6919 - accuracy: 0.6369 - val_loss: 0.6662 - val_accuracy: 0.6905
# Epoch 61/1000
# 168/168 [==============================] - 0s 315us/step - loss: 0.6856 - accuracy: 0.6310 - val_loss: 0.6555 - val_accuracy: 0.6667
# Epoch 62/1000
# 168/168 [==============================] - 0s 274us/step - loss: 0.6787 - accuracy: 0.6369 - val_loss: 0.6535 - val_accuracy: 0.6667
# Epoch 63/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.6774 - accuracy: 0.6369 - val_loss: 0.6524 - val_accuracy: 0.6667
# Epoch 64/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.6700 - accuracy: 0.6369 - val_loss: 0.6553 - val_accuracy: 0.6905
# Epoch 65/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.6680 - accuracy: 0.6429 - val_loss: 0.6547 - val_accuracy: 0.6905
# Epoch 66/1000
# 168/168 [==============================] - 0s 238us/step - loss: 0.6617 - accuracy: 0.6845 - val_loss: 0.6500 - val_accuracy: 0.6429
# Epoch 67/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.6609 - accuracy: 0.6964 - val_loss: 0.6414 - val_accuracy: 0.6667
# Epoch 68/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.6559 - accuracy: 0.6369 - val_loss: 0.6349 - val_accuracy: 0.6905
# Epoch 69/1000
# 168/168 [==============================] - 0s 238us/step - loss: 0.6507 - accuracy: 0.6488 - val_loss: 0.6333 - val_accuracy: 0.6905
# Epoch 70/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.6458 - accuracy: 0.6667 - val_loss: 0.6309 - val_accuracy: 0.6667
# Epoch 71/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.6432 - accuracy: 0.6845 - val_loss: 0.6254 - val_accuracy: 0.6905
# Epoch 72/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.6442 - accuracy: 0.6429 - val_loss: 0.6219 - val_accuracy: 0.6905
# Epoch 73/1000
# 168/168 [==============================] - 0s 268us/step - loss: 0.6368 - accuracy: 0.6607 - val_loss: 0.6175 - val_accuracy: 0.6667
# Epoch 74/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.6366 - accuracy: 0.6786 - val_loss: 0.6179 - val_accuracy: 0.6429
# Epoch 75/1000
# 168/168 [==============================] - 0s 286us/step - loss: 0.6310 - accuracy: 0.6845 - val_loss: 0.6133 - val_accuracy: 0.6667
# Epoch 76/1000
# 168/168 [==============================] - 0s 286us/step - loss: 0.6250 - accuracy: 0.6786 - val_loss: 0.6146 - val_accuracy: 0.6905
# Epoch 77/1000
# 168/168 [==============================] - 0s 399us/step - loss: 0.6244 - accuracy: 0.6964 - val_loss: 0.6134 - val_accuracy: 0.6667
# Epoch 78/1000
# 168/168 [==============================] - 0s 291us/step - loss: 0.6194 - accuracy: 0.7024 - val_loss: 0.6137 - val_accuracy: 0.6905
# Epoch 79/1000
# 168/168 [==============================] - 0s 309us/step - loss: 0.6175 - accuracy: 0.7143 - val_loss: 0.6102 - val_accuracy: 0.6667
# Epoch 80/1000
# 168/168 [==============================] - 0s 280us/step - loss: 0.6133 - accuracy: 0.7143 - val_loss: 0.6093 - val_accuracy: 0.6905
# Epoch 81/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.6135 - accuracy: 0.7024 - val_loss: 0.6097 - val_accuracy: 0.6905
# Epoch 82/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.6084 - accuracy: 0.7083 - val_loss: 0.6015 - val_accuracy: 0.6667
# Epoch 83/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.6039 - accuracy: 0.7321 - val_loss: 0.5919 - val_accuracy: 0.6905
# Epoch 84/1000
# 168/168 [==============================] - 0s 211us/step - loss: 0.5974 - accuracy: 0.7143 - val_loss: 0.5910 - val_accuracy: 0.6429
# Epoch 85/1000
# 168/168 [==============================] - 0s 269us/step - loss: 0.5950 - accuracy: 0.7321 - val_loss: 0.5846 - val_accuracy: 0.6667
# Epoch 86/1000
# 168/168 [==============================] - 0s 215us/step - loss: 0.5900 - accuracy: 0.7083 - val_loss: 0.5818 - val_accuracy: 0.6667
# Epoch 87/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.5878 - accuracy: 0.7202 - val_loss: 0.5781 - val_accuracy: 0.6667
# Epoch 88/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.5845 - accuracy: 0.7440 - val_loss: 0.5769 - val_accuracy: 0.6429
# Epoch 89/1000
# 168/168 [==============================] - 0s 200us/step - loss: 0.5816 - accuracy: 0.7321 - val_loss: 0.5746 - val_accuracy: 0.6905
# Epoch 90/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.5762 - accuracy: 0.7500 - val_loss: 0.5721 - val_accuracy: 0.6429
# Epoch 91/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.5752 - accuracy: 0.7202 - val_loss: 0.5697 - val_accuracy: 0.6905
# Epoch 92/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.5708 - accuracy: 0.7321 - val_loss: 0.5653 - val_accuracy: 0.6429
# Epoch 93/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.5662 - accuracy: 0.7440 - val_loss: 0.5650 - val_accuracy: 0.6667
# Epoch 94/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.5606 - accuracy: 0.7381 - val_loss: 0.5618 - val_accuracy: 0.7143
# Epoch 95/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.5588 - accuracy: 0.7381 - val_loss: 0.5581 - val_accuracy: 0.7143
# Epoch 96/1000
# 168/168 [==============================] - 0s 173us/step - loss: 0.5526 - accuracy: 0.7560 - val_loss: 0.5547 - val_accuracy: 0.6667
# Epoch 97/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.5509 - accuracy: 0.7381 - val_loss: 0.5521 - val_accuracy: 0.6667
# Epoch 98/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.5509 - accuracy: 0.7381 - val_loss: 0.5476 - val_accuracy: 0.7143
# Epoch 99/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.5454 - accuracy: 0.7381 - val_loss: 0.5428 - val_accuracy: 0.6429
# Epoch 100/1000
# 168/168 [==============================] - 0s 167us/step - loss: 0.5388 - accuracy: 0.7500 - val_loss: 0.5401 - val_accuracy: 0.6667
# Epoch 101/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.5353 - accuracy: 0.7500 - val_loss: 0.5416 - val_accuracy: 0.7143
# Epoch 102/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.5359 - accuracy: 0.7500 - val_loss: 0.5325 - val_accuracy: 0.6905
# Epoch 103/1000
# 168/168 [==============================] - 0s 184us/step - loss: 0.5251 - accuracy: 0.7738 - val_loss: 0.5296 - val_accuracy: 0.6905
# Epoch 104/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.5208 - accuracy: 0.7679 - val_loss: 0.5241 - val_accuracy: 0.6905
# Epoch 105/1000
# 168/168 [==============================] - 0s 214us/step - loss: 0.5170 - accuracy: 0.7738 - val_loss: 0.5222 - val_accuracy: 0.7143
# Epoch 106/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.5174 - accuracy: 0.7560 - val_loss: 0.5131 - val_accuracy: 0.6905
# Epoch 107/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.5180 - accuracy: 0.7738 - val_loss: 0.5199 - val_accuracy: 0.6905
# Epoch 108/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.5053 - accuracy: 0.7976 - val_loss: 0.5170 - val_accuracy: 0.7381
# Epoch 109/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.5081 - accuracy: 0.7500 - val_loss: 0.5120 - val_accuracy: 0.7381
# Epoch 110/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.4973 - accuracy: 0.7738 - val_loss: 0.5004 - val_accuracy: 0.7143
# Epoch 111/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4956 - accuracy: 0.7917 - val_loss: 0.4939 - val_accuracy: 0.7143
# Epoch 112/1000
# 168/168 [==============================] - 0s 196us/step - loss: 0.4902 - accuracy: 0.7798 - val_loss: 0.4900 - val_accuracy: 0.7381
# Epoch 113/1000
# 168/168 [==============================] - 0s 173us/step - loss: 0.4833 - accuracy: 0.7976 - val_loss: 0.4870 - val_accuracy: 0.7143
# Epoch 114/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.4812 - accuracy: 0.7917 - val_loss: 0.4896 - val_accuracy: 0.7857
# Epoch 115/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.4708 - accuracy: 0.7917 - val_loss: 0.4851 - val_accuracy: 0.7143
# Epoch 116/1000
# 168/168 [==============================] - 0s 178us/step - loss: 0.4668 - accuracy: 0.8036 - val_loss: 0.4846 - val_accuracy: 0.7857
# Epoch 117/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.4633 - accuracy: 0.8095 - val_loss: 0.4716 - val_accuracy: 0.7381
# Epoch 118/1000
# 168/168 [==============================] - 0s 220us/step - loss: 0.4645 - accuracy: 0.7976 - val_loss: 0.4677 - val_accuracy: 0.7381
# Epoch 119/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.4617 - accuracy: 0.8095 - val_loss: 0.4731 - val_accuracy: 0.7857
# Epoch 120/1000
# 168/168 [==============================] - 0s 256us/step - loss: 0.4500 - accuracy: 0.8214 - val_loss: 0.4613 - val_accuracy: 0.7143
# Epoch 121/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.4527 - accuracy: 0.8155 - val_loss: 0.4549 - val_accuracy: 0.7381
# Epoch 122/1000
# 168/168 [==============================] - 0s 250us/step - loss: 0.4445 - accuracy: 0.8214 - val_loss: 0.4488 - val_accuracy: 0.7857
# Epoch 123/1000
# 168/168 [==============================] - 0s 208us/step - loss: 0.4333 - accuracy: 0.8333 - val_loss: 0.4546 - val_accuracy: 0.8095
# Epoch 124/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4336 - accuracy: 0.8333 - val_loss: 0.4483 - val_accuracy: 0.7619
# Epoch 125/1000
# 168/168 [==============================] - 0s 190us/step - loss: 0.4371 - accuracy: 0.8274 - val_loss: 0.4465 - val_accuracy: 0.7619
# Epoch 126/1000
# 168/168 [==============================] - 0s 244us/step - loss: 0.4226 - accuracy: 0.8274 - val_loss: 0.4606 - val_accuracy: 0.7857
# Epoch 127/1000
# 168/168 [==============================] - 0s 262us/step - loss: 0.4329 - accuracy: 0.8274 - val_loss: 0.4385 - val_accuracy: 0.8095
# Epoch 128/1000
# 168/168 [==============================] - 0s 232us/step - loss: 0.4157 - accuracy: 0.8571 - val_loss: 0.4330 - val_accuracy: 0.7857
# Epoch 129/1000
# 168/168 [==============================] - 0s 202us/step - loss: 0.4110 - accuracy: 0.8452 - val_loss: 0.4297 - val_accuracy: 0.7619
# Epoch 130/1000
# ...
# Epoch 751/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2053 - accuracy: 0.9405 - val_loss: 0.2356 - val_accuracy: 0.9286
# Epoch 752/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1991 - accuracy: 0.9464 - val_loss: 0.2491 - val_accuracy: 0.9286
# Epoch 753/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2080 - accuracy: 0.9405 - val_loss: 0.2265 - val_accuracy: 0.9286
# Epoch 754/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2038 - accuracy: 0.9583 - val_loss: 0.2603 - val_accuracy: 0.9524
# Epoch 755/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1996 - accuracy: 0.9464 - val_loss: 0.2304 - val_accuracy: 0.9286
# Epoch 756/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2145 - accuracy: 0.9286 - val_loss: 0.2207 - val_accuracy: 0.9286
# Epoch 757/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.2129 - accuracy: 0.9286 - val_loss: 0.2509 - val_accuracy: 0.9286
# Epoch 758/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1980 - accuracy: 0.9524 - val_loss: 0.2432 - val_accuracy: 0.9286
# Epoch 759/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.2139 - accuracy: 0.9345 - val_loss: 0.2321 - val_accuracy: 0.9286
# Epoch 760/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2038 - accuracy: 0.9524 - val_loss: 0.2462 - val_accuracy: 0.9286
# Epoch 761/1000
# 168/168 [==============================] - 0s 95us/step - loss: 0.1988 - accuracy: 0.9464 - val_loss: 0.2416 - val_accuracy: 0.9048
# Epoch 762/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2014 - accuracy: 0.9464 - val_loss: 0.2368 - val_accuracy: 0.9286
# Epoch 763/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.2115 - accuracy: 0.9345 - val_loss: 0.2451 - val_accuracy: 0.9286
# Epoch 764/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1974 - accuracy: 0.9583 - val_loss: 0.2469 - val_accuracy: 0.9286
# Epoch 765/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2120 - accuracy: 0.9464 - val_loss: 0.2485 - val_accuracy: 0.9286
# Epoch 766/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2077 - accuracy: 0.9405 - val_loss: 0.2369 - val_accuracy: 0.9286
# Epoch 767/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2275 - accuracy: 0.9405 - val_loss: 0.2374 - val_accuracy: 0.9286
# Epoch 768/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.2109 - accuracy: 0.9464 - val_loss: 0.2251 - val_accuracy: 0.9286
# Epoch 769/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2056 - accuracy: 0.9345 - val_loss: 0.2368 - val_accuracy: 0.9286
# Epoch 770/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.2242 - accuracy: 0.9405 - val_loss: 0.2181 - val_accuracy: 0.9286
# Epoch 771/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2069 - accuracy: 0.9405 - val_loss: 0.2495 - val_accuracy: 0.9286
# Epoch 772/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1958 - accuracy: 0.9405 - val_loss: 0.2292 - val_accuracy: 0.9286
# Epoch 773/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.1942 - accuracy: 0.9464 - val_loss: 0.2430 - val_accuracy: 0.9048
# Epoch 774/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.2100 - accuracy: 0.9167 - val_loss: 0.2240 - val_accuracy: 0.9286
# Epoch 775/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.2055 - accuracy: 0.9345 - val_loss: 0.2581 - val_accuracy: 0.9524
# Epoch 776/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.2216 - accuracy: 0.9524 - val_loss: 0.2331 - val_accuracy: 0.9286
# Epoch 777/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2079 - accuracy: 0.9405 - val_loss: 0.2293 - val_accuracy: 0.9286
# Epoch 778/1000
# 168/168 [==============================] - 0s 131us/step - loss: 0.1950 - accuracy: 0.9524 - val_loss: 0.2589 - val_accuracy: 0.9286
# Epoch 779/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1918 - accuracy: 0.9405 - val_loss: 0.2232 - val_accuracy: 0.9286
# Epoch 780/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1947 - accuracy: 0.9345 - val_loss: 0.2605 - val_accuracy: 0.9286
# Epoch 781/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1946 - accuracy: 0.9524 - val_loss: 0.2290 - val_accuracy: 0.9286
# Epoch 782/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2083 - accuracy: 0.9167 - val_loss: 0.2196 - val_accuracy: 0.9286
# Epoch 783/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1902 - accuracy: 0.9464 - val_loss: 0.2600 - val_accuracy: 0.9286
# Epoch 784/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1985 - accuracy: 0.9286 - val_loss: 0.2505 - val_accuracy: 0.9524
# Epoch 785/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1876 - accuracy: 0.9464 - val_loss: 0.2179 - val_accuracy: 0.9286
# Epoch 786/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1966 - accuracy: 0.9345 - val_loss: 0.2314 - val_accuracy: 0.9286
# Epoch 787/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1892 - accuracy: 0.9464 - val_loss: 0.2824 - val_accuracy: 0.9286
# Epoch 788/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2024 - accuracy: 0.9405 - val_loss: 0.2387 - val_accuracy: 0.9286
# Epoch 789/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.2173 - accuracy: 0.9345 - val_loss: 0.2167 - val_accuracy: 0.9286
# Epoch 790/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2076 - accuracy: 0.9345 - val_loss: 0.2763 - val_accuracy: 0.9286
# Epoch 791/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2005 - accuracy: 0.9226 - val_loss: 0.2143 - val_accuracy: 0.9286
# Epoch 792/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2029 - accuracy: 0.9405 - val_loss: 0.2373 - val_accuracy: 0.9286
# Epoch 793/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1965 - accuracy: 0.9524 - val_loss: 0.2460 - val_accuracy: 0.9048
# Epoch 794/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2118 - accuracy: 0.9286 - val_loss: 0.2147 - val_accuracy: 0.9286
# Epoch 795/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.2055 - accuracy: 0.9286 - val_loss: 0.2852 - val_accuracy: 0.8810
# Epoch 796/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.2039 - accuracy: 0.9286 - val_loss: 0.2295 - val_accuracy: 0.9048
# Epoch 797/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2069 - accuracy: 0.9345 - val_loss: 0.2461 - val_accuracy: 0.9048
# Epoch 798/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.2084 - accuracy: 0.9226 - val_loss: 0.2826 - val_accuracy: 0.9286
# Epoch 799/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1890 - accuracy: 0.9464 - val_loss: 0.2200 - val_accuracy: 0.9048
# Epoch 800/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1810 - accuracy: 0.9405 - val_loss: 0.2553 - val_accuracy: 0.9286
# Epoch 801/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1910 - accuracy: 0.9345 - val_loss: 0.2566 - val_accuracy: 0.9286
# Epoch 802/1000
# 168/168 [==============================] - 0s 77us/step - loss: 0.1838 - accuracy: 0.9524 - val_loss: 0.2210 - val_accuracy: 0.9286
# Epoch 803/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1879 - accuracy: 0.9464 - val_loss: 0.2168 - val_accuracy: 0.9286
# Epoch 804/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1842 - accuracy: 0.9405 - val_loss: 0.2192 - val_accuracy: 0.9286
# Epoch 805/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1805 - accuracy: 0.9583 - val_loss: 0.2423 - val_accuracy: 0.9286
# Epoch 806/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1855 - accuracy: 0.9405 - val_loss: 0.2354 - val_accuracy: 0.9286
# Epoch 807/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1899 - accuracy: 0.9464 - val_loss: 0.2181 - val_accuracy: 0.9286
# Epoch 808/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1861 - accuracy: 0.9464 - val_loss: 0.2346 - val_accuracy: 0.9286
# Epoch 809/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1782 - accuracy: 0.9524 - val_loss: 0.2267 - val_accuracy: 0.9286
# Epoch 810/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.1790 - accuracy: 0.9583 - val_loss: 0.2408 - val_accuracy: 0.9286
# Epoch 811/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1784 - accuracy: 0.9583 - val_loss: 0.2306 - val_accuracy: 0.9286
# Epoch 812/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1800 - accuracy: 0.9583 - val_loss: 0.2223 - val_accuracy: 0.9286
# Epoch 813/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1850 - accuracy: 0.9524 - val_loss: 0.2333 - val_accuracy: 0.9286
# Epoch 814/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1815 - accuracy: 0.9405 - val_loss: 0.2131 - val_accuracy: 0.9286
# Epoch 815/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1774 - accuracy: 0.9464 - val_loss: 0.2724 - val_accuracy: 0.9286
# Epoch 816/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1976 - accuracy: 0.9226 - val_loss: 0.2384 - val_accuracy: 0.9524
# Epoch 817/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1881 - accuracy: 0.9524 - val_loss: 0.2134 - val_accuracy: 0.9048
# Epoch 818/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1877 - accuracy: 0.9524 - val_loss: 0.2531 - val_accuracy: 0.9286
# Epoch 819/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1833 - accuracy: 0.9464 - val_loss: 0.2166 - val_accuracy: 0.9286
# Epoch 820/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1762 - accuracy: 0.9524 - val_loss: 0.2318 - val_accuracy: 0.9286
# Epoch 821/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1823 - accuracy: 0.9524 - val_loss: 0.2460 - val_accuracy: 0.9524
# Epoch 822/1000
# 168/168 [==============================] - 0s 131us/step - loss: 0.1723 - accuracy: 0.9524 - val_loss: 0.2119 - val_accuracy: 0.9048
# Epoch 823/1000
# 168/168 [==============================] - 0s 137us/step - loss: 0.1812 - accuracy: 0.9405 - val_loss: 0.2213 - val_accuracy: 0.9286
# Epoch 824/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.1834 - accuracy: 0.9464 - val_loss: 0.2727 - val_accuracy: 0.9286
# Epoch 825/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1803 - accuracy: 0.9345 - val_loss: 0.2152 - val_accuracy: 0.9286
# Epoch 826/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1835 - accuracy: 0.9464 - val_loss: 0.2226 - val_accuracy: 0.9286
# Epoch 827/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1874 - accuracy: 0.9524 - val_loss: 0.2320 - val_accuracy: 0.9286
# Epoch 828/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1954 - accuracy: 0.9524 - val_loss: 0.2164 - val_accuracy: 0.9286
# Epoch 829/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1831 - accuracy: 0.9405 - val_loss: 0.2244 - val_accuracy: 0.9048
# Epoch 830/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1766 - accuracy: 0.9464 - val_loss: 0.2456 - val_accuracy: 0.9286
# Epoch 831/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.1827 - accuracy: 0.9464 - val_loss: 0.2318 - val_accuracy: 0.9048
# Epoch 832/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2141 - accuracy: 0.9107 - val_loss: 0.2038 - val_accuracy: 0.9524
# Epoch 833/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.2026 - accuracy: 0.9405 - val_loss: 0.2768 - val_accuracy: 0.9286
# Epoch 834/1000
# 168/168 [==============================] - 0s 131us/step - loss: 0.1806 - accuracy: 0.9345 - val_loss: 0.2201 - val_accuracy: 0.9286
# Epoch 835/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1834 - accuracy: 0.9286 - val_loss: 0.2137 - val_accuracy: 0.9286
# Epoch 836/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1931 - accuracy: 0.9464 - val_loss: 0.2301 - val_accuracy: 0.9286
# Epoch 837/1000
# 168/168 [==============================] - 0s 125us/step - loss: 0.1841 - accuracy: 0.9524 - val_loss: 0.2500 - val_accuracy: 0.9048
# Epoch 838/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1732 - accuracy: 0.9464 - val_loss: 0.2208 - val_accuracy: 0.9286
# Epoch 839/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1728 - accuracy: 0.9524 - val_loss: 0.2250 - val_accuracy: 0.9048
# Epoch 840/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1805 - accuracy: 0.9345 - val_loss: 0.2175 - val_accuracy: 0.9286
# Epoch 841/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1768 - accuracy: 0.9524 - val_loss: 0.2664 - val_accuracy: 0.9286
# Epoch 842/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1753 - accuracy: 0.9405 - val_loss: 0.2052 - val_accuracy: 0.9286
# Epoch 843/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1779 - accuracy: 0.9405 - val_loss: 0.2315 - val_accuracy: 0.9286
# Epoch 844/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1691 - accuracy: 0.9464 - val_loss: 0.2420 - val_accuracy: 0.9048
# Epoch 845/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1695 - accuracy: 0.9524 - val_loss: 0.2241 - val_accuracy: 0.9286
# Epoch 846/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1724 - accuracy: 0.9524 - val_loss: 0.2163 - val_accuracy: 0.9286
# Epoch 847/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1745 - accuracy: 0.9464 - val_loss: 0.2085 - val_accuracy: 0.9286
# Epoch 848/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1832 - accuracy: 0.9405 - val_loss: 0.2228 - val_accuracy: 0.9286
# Epoch 849/1000
# 168/168 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.96 - 0s 107us/step - loss: 0.1830 - accuracy: 0.9405 - val_loss: 0.2404 - val_accuracy: 0.9286
# Epoch 850/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1761 - accuracy: 0.9405 - val_loss: 0.2196 - val_accuracy: 0.9048
# Epoch 851/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1742 - accuracy: 0.9583 - val_loss: 0.2438 - val_accuracy: 0.9286
# Epoch 852/1000
# 168/168 [==============================] - 0s 119us/step - loss: 0.1776 - accuracy: 0.9524 - val_loss: 0.2313 - val_accuracy: 0.9286
# Epoch 853/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1691 - accuracy: 0.9464 - val_loss: 0.2234 - val_accuracy: 0.9286
# Epoch 854/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1719 - accuracy: 0.9524 - val_loss: 0.2125 - val_accuracy: 0.9286
# Epoch 855/1000
# 168/168 [==============================] - 0s 107us/step - loss: 0.1772 - accuracy: 0.9345 - val_loss: 0.2103 - val_accuracy: 0.9286
# Epoch 856/1000
# 168/168 [==============================] - 0s 113us/step - loss: 0.1690 - accuracy: 0.9464 - val_loss: 0.2468 - val_accuracy: 0.9286
# Epoch 857/1000
# 168/168 [==============================] - 0s 101us/step - loss: 0.1801 - accuracy: 0.9464 - val_loss: 0.2162 - val_accuracy: 0.9286

# %%
# Make predictions on the test sets
pred1 = nn.predict(X_test)
pred2 = nn2.predict(X2_test)
pred3 = nn3.predict(X3_test)

# %%
# Score the models' performance
score = nn.evaluate(X_test, y_test)
score2 = nn2.evaluate(X2_test, y2_test)
score3 = nn3.evaluate(X3_test, y3_test)
# Out:
# 42/42 [==============================] - 0s 428us/step
# 42/42 [==============================] - 0s 333us/step
# 42/42 [==============================] - 0s 452us/step

# %%
# Get the scores
loss, accuracy = score
loss2, accuracy2 = score2
loss3, accuracy3 = score3

print('\nTest loss:', round(loss,4), '   Test accuracy:', round(accuracy,4)*100,'%')
print('\nTest2 loss:', round(loss2,4), '   Test2 accuracy:', round(accuracy2,4)*100,'%')
print('\nTest3 loss:', round(loss3,4), '   Test3 accuracy:', round(accuracy3,4)*100,'%')
# Out:
# Test loss: 0.3024    Test accuracy: 85.71 %
#
# Test2 loss: 0.2677    Test2 accuracy: 88.1 %
#
# Test3 loss: 0.2162    Test3 accuracy: 92.86 %

# %%
# Create plots
_=plt.figure(figsize=(14,7))
_=plt.subplot(3,1,1)
_=plt.title('Neural Network 1 Performance')
_=plt.plot(nn_fit.history['val_loss'], 'k')
_=plt.plot(nn_fit.history['val_accuracy'])
_=plt.ylim(loss-.2,1)
_=plt.axhline(max(nn_fit.history['val_accuracy']), linestyle=':', linewidth=1)
_=plt.axhline(min(nn_fit.history['val_loss']), linestyle=':', linewidth=1, c='k')
_=plt.axhline(loss, linestyle='-.', linewidth=2, c='r')
_=plt.axhline(accuracy, linestyle='-.', linewidth=2, c='g')
_=plt.xlabel('Epochs')

_=plt.subplot(3,1,2)
_=plt.title('Neural Network 2 Performance')
_=plt.plot(nn2_fit.history['val_loss'], 'k')
_=plt.plot(nn2_fit.history['val_accuracy'])
_=plt.ylim(loss2-.2,1)
_=plt.axhline(max(nn2_fit.history['val_accuracy']), linestyle=':', linewidth=1)
_=plt.axhline(min(nn2_fit.history['val_loss']), linestyle=':', linewidth=1, c='k')
_=plt.axhline(loss2, linestyle='-.', linewidth=2, c='r')
_=plt.axhline(accuracy2, linestyle='-.', linewidth=2, c='g')
_=plt.xlabel('Epochs')
_=plt.ylabel('Validation score')
_=plt.legend(['validation loss','validation accuracy', 'accuracy max', 'loss min', 'test loss', 'test accuracy'])

_=plt.subplot(3,1,3)
_=plt.title('Neural Network 3 Performance')
_=plt.plot(nn3_fit.history['val_loss'], 'k')
_=plt.plot(nn3_fit.history['val_accuracy'])
#_=plt.ylim(loss3-.2,1)
_=plt.axhline(max(nn3_fit.history['val_accuracy']), linestyle=':', linewidth=1)
_=plt.axhline(min(nn3_fit.history['val_loss']), linestyle=':', linewidth=1, c='k')
_=plt.axhline(loss3, linestyle='-.', linewidth=2, c='r')
_=plt.axhline(accuracy3, linestyle='-.', linewidth=2, c='g')
_=plt.xlabel('Epochs')
_=plt.tight_layout()

plt.show()

# %%
# Calculate the roc curve and auc score for each class
X = seeds.drop('class', axis =1)
y = seeds['class']

# Convert the probabilities into class labels
pred3_classes = []
for i in range(len(pred3_df)):
    pred3_classes.append(np.argmax(pred3_df.iloc[i,:]) + 1)
pred3_classes = np.asarray(pred3_classes)

# Binarize the predicted classes
#pred1_bin = label_binarize(pred1, classes = [1, 2, 3])
#pred2_bin = label_binarize(pred2, classes = [1, 2, 3])
pred3_bin = label_binarize(pred3_classes, classes = [1, 2, 3])


# Binarize the training and test original data for comparison
#y_test_bin = label_binarize(y_test, classes = [1, 2, 3])
#y2_test_bin = label_binarize(y2_test, classes = [1, 2, 3])
y3_test_bin = label_binarize(y3_test, classes = [1, 2, 3])

# Set thenumber of classes
num_classes = y3_test_bin.shape[1]

# Loop through classes and caclulate roc
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y3_test_bin[:, i], pred3_bin[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    
# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y3_test_bin.ravel(), pred3_bin.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(num_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Average it and compute AUC
mean_tpr /= num_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot the curve
plt.figure(figsize = (12, 7))
plt.plot(fpr[0], tpr[0], label = 'Kama ROC curve (area = %.2f)' % roc_auc[0])
plt.plot(fpr[1], tpr[1], label = 'Rosa ROC curve (area = %.2f)' % roc_auc[1])
plt.plot(fpr['micro'], tpr['micro'], label='micro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':')
plt.plot(fpr['macro'], tpr['macro'], label='macro-average ROC curve (area = {0:0.2f})'
               ''.format(roc_auc["macro"]),
         color='red', linestyle=':')
plt.plot(fpr[2], tpr[2], label = 'Canadian ROC curve (area = %.2f)' % roc_auc[2])
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.title('Seeds ROC Curves: Test Set')
plt.legend(loc = 'lower right')

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The seeds dataset, though small, is rich in information. The logistic regression model performed best, with a neural network showing similar results using features with those highly correlated removed. The next step in training the model would be to use each network in a larger inhereted neural network structure.
